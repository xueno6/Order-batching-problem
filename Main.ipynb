# %%
import numpy as np
# %run Sub_Class.ipynb
s= Problem_MIP(number_of_order=30, number_of_sku=300, number_of_unique_sku=200, number_of_batch=3)

# %%
s.To_Original()

# %%
s.
# Out:
# (0, 74)
# (0, 1336)
# (1, 302)
# (35, 902)
# (74, 1336)
# (88, 778)
# (121, 1536)
# (142, 589)
# (142, 754)
# (142, 908)
# (213, 820)
# (250, 933)
# (250, 1015)
# (250, 1403)
# (302, 467)
# (302, 1060)
# (302, 1295)
# (318, 1525)
# (413, 1320)
# (422, 680)
# (422, 983)
# (422, 1398)
# (422, 1541)
# (452, 481)
# (452, 778)
# (452, 975)
# (452, 1380)
# (452, 1519)
# (478, 1423)
# (481, 975)
# (481, 1380)
# (481, 1519)
# (485, 834)
# (500, 1040)
# (500, 1093)
# (506, 1399)
# (540, 1506)
# (656, 1158)
# (656, 1320)
# (680, 983)
# (680, 1398)
# (680, 1541)
# (692, 1003)
# (703, 971)
# (703, 1055)
# (703, 1536)
# (812, 901)
# (830, 1049)
# (836, 1139)
# (841, 1088)
# (877, 907)
# (877, 1074)
# (888, 1326)
# (892, 911)
# (901, 933)
# (907, 1074)
# (933, 1015)
# (933, 1403)
# (971, 1055)
# (971, 1536)
# (975, 1380)
# (975, 1519)
# (983, 1398)
# (983, 1541)
# (1010, 1050)
# (1010, 1435)
# (1015, 1403)
# (1023, 1038)
# (1040, 1093)
# (1040, 1106)
# (1050, 1241)
# (1055, 1536)
# (1093, 1106)
# ...

# %%
# Out:
# {'weight': 2}
